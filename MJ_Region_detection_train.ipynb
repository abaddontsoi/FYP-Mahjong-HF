# %%
import torch

if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)} is available.")
    device = torch.device("cuda")
else:
    print("No GPU available. PyTorch will run on CPU.")
    device = torch.device("cpu")

print(f"Using device: {device}")

# %%
import torch, torchvision
print("torch:", torch.__version__, "cuda:", torch.version.cuda)
print("torchvision:", torchvision.__version__)
print("cuda available:", torch.cuda.is_available())

# %%
# For normal training
from ultralytics import YOLO

model = YOLO('yolo11m.pt')
# model.reset_weights()


result = model.train(
    data='./yolo11.yaml',
    epochs=50,
    imgsz=1088,
    pretrained=False,
    patience=15,
    device=0,
    optimizer='AdamW'
)

# %%
model.save('MJ_tile_detection_yolo11.pt')

# %%
# For obb
from ultralytics import YOLO

model = YOLO('yolo11m-obb.pt')
# model.reset_weights()


result = model.train(
    data='./yolo11.yaml',
    epochs=50,
    imgsz=1088,
    pretrained=False,
    patience=15,
    device=0,
)
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11m-obb.pt to 'yolo11m-obb.pt': 100% ━━━━━━━━━━━━ 40.5MB 10.7MB/s 3.8s.8s<0.1ss
# New https://pypi.org/project/ultralytics/8.4.8 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.243  Python-3.14.0 torch-2.9.1+cu130 CUDA:0 (NVIDIA RTX 4000 Ada Generation, 20474MiB)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=./yolo11.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=50, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=1088, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11m-obb.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=15, perspective=0.0, plots=True, pose=12.0, pretrained=False, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=D:\FYP-Tile-Detection\runs\obb\train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=obb, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  1    111872  ultralytics.nn.modules.block.C3k2            [128, 256, 1, True, 0.25]
#   3                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   4                  -1  1    444928  ultralytics.nn.modules.block.C3k2            [256, 512, 1, True, 0.25]
#   5                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   6                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1   1642496  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    542720  ultralytics.nn.modules.block.C3k2            [1024, 256, 1, True]
#  17                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  20                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1642496  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True]
#  23        [16, 19, 22]  1   2260630  ultralytics.nn.modules.head.OBB              [1, 1, [256, 512, 512]]
# YOLO11m-obb summary: 246 layers, 20,902,614 parameters, 20,902,598 gradients, 71.9 GFLOPs
#
# Transferred 685/691 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed
# train: Fast image access  (ping: 0.00.0 ms, read: 7.84.2 MB/s, size: 36.0 KB)
# train: Scanning D:\FYP-Mahjong-HF\data\train\labels... 252 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 252/252 933.9it/s 0.3s0.1s
# train: New cache created: D:\FYP-Mahjong-HF\data\train\labels.cache
# val: Fast image access  (ping: 0.10.0 ms, read: 4.52.7 MB/s, size: 35.8 KB)
# val: Scanning D:\FYP-Mahjong-HF\data\valid\labels... 24 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 24/24 393.5it/s 0.1s
# val: New cache created: D:\FYP-Mahjong-HF\data\valid\labels.cache
# Plotting labels to D:\FYP-Tile-Detection\runs\obb\train\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 112 weight(decay=0.0), 122 weight(decay=0.0005), 121 bias(decay=0.0)
# Image sizes 1088 train, 1088 val
# Using 8 dataloader workers
# Logging results to D:\FYP-Tile-Detection\runs\obb\train
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      24.3G      1.635      2.818      1.968        380       1088: 100% ━━━━━━━━━━━━ 16/16 10.0s/it 2:40.2s0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.3it/s 1.6s2.6s
#                    all         24        727      0.809      0.865        0.9      0.525
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      24.5G      1.037     0.9653      1.424        824       1088: 100% ━━━━━━━━━━━━ 16/16 8.0s/it 2:088.9ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.5it/s 1.4s2.9s
#                    all         24        727      0.942      0.945       0.98      0.824
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      23.7G     0.9265     0.7047      1.486        614       1088: 100% ━━━━━━━━━━━━ 16/16 7.7s/it 2:036.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.9s/it 5.7s<11.2s
#                    all         24        727      0.974      0.968      0.991      0.852
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      24.5G     0.9289       0.63      1.488        722       1088: 100% ━━━━━━━━━━━━ 16/16 10.3s/it 2:45.3s8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.4s/it 2.7s6.0s
#                    all         24        727      0.975      0.977      0.992      0.866
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50      23.5G     0.8879     0.5862       1.54        513       1088: 100% ━━━━━━━━━━━━ 16/16 7.2s/it 1:555.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.3s/it 4.6s6.6s
#                    all         24        727      0.978      0.978      0.993      0.859
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50      23.7G     0.8374     0.5277      1.482        752       1088: 100% ━━━━━━━━━━━━ 16/16 7.0s/it 1:525.8ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.1it/s 1.8s3.2s
#                    all         24        727      0.986      0.968      0.993      0.895
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50      23.7G     0.8564     0.5412      1.514        763       1088: 100% ━━━━━━━━━━━━ 16/16 9.2s/it 2:277.0sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.7it/s 1.2s2.8s
#                    all         24        727      0.985      0.961      0.992      0.865
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50      23.5G     0.8023     0.4732      1.482        818       1088: 100% ━━━━━━━━━━━━ 16/16 7.9s/it 2:066.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.8it/s 0.7s1.6s
#                    all         24        727      0.979      0.968      0.993      0.886
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50        24G     0.8732     0.4823       1.53        730       1088: 100% ━━━━━━━━━━━━ 16/16 9.6s/it 2:347.6s0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.2it/s 1.6s3.5s
#                    all         24        727      0.987      0.967      0.993      0.889
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50      23.6G     0.8156     0.4669      1.465        646       1088: 100% ━━━━━━━━━━━━ 16/16 7.1s/it 1:536.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.1it/s 1.0s2.1s
#                    all         24        727      0.972      0.972      0.993        0.9
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/50        24G     0.7969     0.4515       1.43        814       1088: 100% ━━━━━━━━━━━━ 16/16 6.2s/it 1:395.9ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.2it/s 0.9s2.0s
#                    all         24        727      0.983      0.964      0.993      0.902
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/50      23.8G     0.7491     0.4389      1.436        564       1088: 100% ━━━━━━━━━━━━ 16/16 5.1s/it 1:215.1sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.3it/s 0.9s2.0s
#                    all         24        727      0.975      0.975      0.992      0.905
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/50        24G     0.7806     0.4329      1.446        609       1088: 100% ━━━━━━━━━━━━ 16/16 5.2s/it 1:245.2sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.5it/s 0.8s1.7s
#                    all         24        727      0.983      0.976      0.994       0.91
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/50      24.4G     0.7459     0.4254       1.42        657       1088: 100% ━━━━━━━━━━━━ 16/16 6.2s/it 1:406.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.6it/s 0.8s1.7s
#                    all         24        727      0.979      0.984      0.993      0.919
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/50      23.9G     0.7785     0.4353      1.512        489       1088: 100% ━━━━━━━━━━━━ 16/16 8.4s/it 2:156.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.9it/s 0.7s1.5s
#                    all         24        727      0.971      0.963      0.992      0.906
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/50      23.8G     0.7374     0.4418      1.397        675       1088: 100% ━━━━━━━━━━━━ 16/16 7.3s/it 1:576.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.6it/s 0.8s1.8s
#                    all         24        727      0.978       0.97      0.993      0.924
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/50      23.8G     0.7092     0.4139      1.351        772       1088: 100% ━━━━━━━━━━━━ 16/16 6.5s/it 1:445.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.7it/s 0.7s1.7s
#                    all         24        727      0.978      0.979      0.994      0.914
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/50      24.8G     0.7524     0.4251      1.382        882       1088: 100% ━━━━━━━━━━━━ 16/16 7.1s/it 1:547.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.7it/s 0.7s1.7s
#                    all         24        727      0.976      0.985      0.994      0.928
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/50      23.8G     0.7136      0.395      1.363        508       1088: 100% ━━━━━━━━━━━━ 16/16 8.8s/it 2:206.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.7it/s 0.7s1.6s
#                    all         24        727      0.984      0.964      0.993      0.919
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/50      23.9G     0.7043     0.3951      1.399        537       1088: 100% ━━━━━━━━━━━━ 16/16 7.9s/it 2:065.7ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.4it/s 0.8s1.9s
#                    all         24        727      0.981       0.97      0.993      0.917
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/50      23.9G      0.704     0.4098      1.373        597       1088: 100% ━━━━━━━━━━━━ 16/16 8.4s/it 2:156.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.0it/s 1.0s2.2s
#                    all         24        727      0.987      0.971      0.993      0.929
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/50      23.6G     0.7056     0.3952      1.391        501       1088: 100% ━━━━━━━━━━━━ 16/16 8.5s/it 2:167.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.6it/s 0.8s1.7s
#                    all         24        727       0.97      0.979      0.993      0.922
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/50      24.5G      0.653      0.377      1.356        452       1088: 100% ━━━━━━━━━━━━ 16/16 8.1s/it 2:097.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.0it/s 1.0s2.1s
#                    all         24        727      0.969      0.991      0.993      0.926
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/50      24.4G     0.6672     0.3773      1.348        851       1088: 100% ━━━━━━━━━━━━ 16/16 9.0s/it 2:248.7ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.6s/it 3.2s5.5s
#                    all         24        727      0.969      0.981      0.993      0.935
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/50      23.8G     0.7113     0.3929      1.377        725       1088: 100% ━━━━━━━━━━━━ 16/16 8.0s/it 2:076.7ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.9it/s 0.7s1.5s
#                    all         24        727      0.985      0.972      0.994      0.916
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/50      23.6G     0.6569     0.3814      1.332        668       1088: 100% ━━━━━━━━━━━━ 16/16 6.9s/it 1:505.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.4it/s 0.8s1.9s
#                    all         24        727      0.978      0.987      0.993      0.932
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/50      23.7G     0.7156     0.4012      1.388        539       1088: 100% ━━━━━━━━━━━━ 16/16 7.1s/it 1:536.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.7it/s 0.7s1.6s
#                    all         24        727      0.966      0.988      0.993      0.929
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/50      24.6G     0.6826     0.3917      1.339        680       1088: 100% ━━━━━━━━━━━━ 16/16 8.6s/it 2:187.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.1s/it 2.1s4.2s
#                    all         24        727      0.973      0.988      0.994      0.927
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/50      24.2G     0.6646     0.3606      1.323        966       1088: 100% ━━━━━━━━━━━━ 16/16 7.7s/it 2:047.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.1it/s 1.0s2.1s
#                    all         24        727      0.971      0.986      0.994      0.944
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/50      23.3G     0.6763     0.3781      1.317        321       1088: 100% ━━━━━━━━━━━━ 16/16 6.7s/it 1:475.8ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.3it/s 0.9s1.8s
#                    all         24        727      0.985      0.981      0.994      0.921
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/50      23.9G     0.6807     0.3845      1.308        705       1088: 100% ━━━━━━━━━━━━ 16/16 6.2s/it 1:396.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.5it/s 0.8s1.8s
#                    all         24        727      0.983      0.981      0.994       0.93
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/50      23.7G     0.6564     0.3638      1.322        707       1088: 100% ━━━━━━━━━━━━ 16/16 8.0s/it 2:087.8ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.8s/it 3.5s6.3s
#                    all         24        727      0.978      0.985      0.994      0.942
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/50      23.7G     0.5772       0.34      1.256        444       1088: 100% ━━━━━━━━━━━━ 16/16 9.3s/it 2:287.6s7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.8it/s 1.1s2.3s
#                    all         24        727      0.974       0.99      0.994      0.941
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/50      23.6G      0.623     0.3564      1.305        515       1088: 100% ━━━━━━━━━━━━ 16/16 8.2s/it 2:117.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.0it/s 1.0s2.1s
#                    all         24        727      0.981       0.98      0.994      0.943
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/50      23.8G     0.6317     0.3589      1.311        520       1088: 100% ━━━━━━━━━━━━ 16/16 10.0s/it 2:41.2s8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.9it/s 1.1s2.3s
#                    all         24        727      0.975      0.986      0.994      0.943
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/50      26.4G     0.6012     0.3453      1.285        650       1088: 100% ━━━━━━━━━━━━ 16/16 13.1s/it 3:2912.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.7it/s 1.2s2.6s
#                    all         24        727      0.982      0.986      0.994      0.938
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/50      23.7G     0.5961     0.3417      1.265        635       1088: 100% ━━━━━━━━━━━━ 16/16 9.1s/it 2:268.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.0it/s 1.0s2.2s
#                    all         24        727      0.978      0.989      0.994      0.941
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/50      24.4G     0.6024     0.3486      1.285        884       1088: 100% ━━━━━━━━━━━━ 16/16 7.1s/it 1:537.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.2it/s 0.9s2.0s
#                    all         24        727      0.979      0.988      0.994      0.942
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/50      23.8G     0.5893     0.3321      1.275        551       1088: 100% ━━━━━━━━━━━━ 16/16 10.3s/it 2:44.2s9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.1it/s 0.9s2.0s
#                    all         24        727      0.978      0.989      0.994      0.946
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/50      24.9G     0.5908     0.3387      1.265        784       1088: 100% ━━━━━━━━━━━━ 16/16 11.0s/it 2:56.4s7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.2s/it 2.4s4.6s
#                    all         24        727      0.971      0.982      0.994       0.94
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/50      23.1G     0.5695     0.3274      1.281        395       1088: 100% ━━━━━━━━━━━━ 16/16 9.5s/it 2:327.1sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.1it/s 0.6s1.4s
#                    all         24        727      0.971      0.988      0.994      0.942
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/50      23.1G     0.6072     0.3381       1.33        467       1088: 100% ━━━━━━━━━━━━ 16/16 8.7s/it 2:207.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.0s/it 2.0s4.5s
#                    all         24        727      0.973      0.985      0.994      0.944
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/50        23G     0.5617      0.322      1.249        642       1088: 100% ━━━━━━━━━━━━ 16/16 8.2s/it 2:126.8ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.0it/s 1.0s2.1s
#                    all         24        727      0.975      0.979      0.993       0.94
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/50        23G     0.5604     0.3215      1.271        295       1088: 100% ━━━━━━━━━━━━ 16/16 9.5s/it 2:337.6sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.2it/s 0.9s1.9s
#                    all         24        727      0.973       0.99      0.994      0.942
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/50        23G     0.5469     0.3282       1.25        222       1088: 100% ━━━━━━━━━━━━ 16/16 8.4s/it 2:146.7ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.3it/s 0.9s1.8s
#                    all         24        727      0.979      0.984      0.994      0.949
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/50      23.5G     0.5409     0.3158      1.266        290       1088: 100% ━━━━━━━━━━━━ 16/16 8.7s/it 2:197.8ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.3it/s 0.9s1.9s
#                    all         24        727      0.972      0.988      0.994      0.943
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50      23.1G     0.5442     0.3065      1.268        279       1088: 100% ━━━━━━━━━━━━ 16/16 9.5s/it 2:328.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.5it/s 0.8s1.7s
#                    all         24        727      0.972       0.99      0.994      0.945
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50        23G      0.527     0.3059      1.227        227       1088: 100% ━━━━━━━━━━━━ 16/16 9.3s/it 2:287.8ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.8it/s 1.1s2.5s
#                    all         24        727      0.983      0.983      0.994      0.948
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50      23.5G     0.5141     0.2992      1.208        289       1088: 100% ━━━━━━━━━━━━ 16/16 8.4s/it 2:157.7ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.3it/s 0.9s1.8s
#                    all         24        727      0.987      0.982      0.994      0.952
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50      23.6G     0.5146     0.3064      1.224        265       1088: 100% ━━━━━━━━━━━━ 16/16 8.7s/it 2:197.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.7it/s 1.2s2.6s
#                    all         24        727      0.982      0.982      0.994       0.95
#
# 50 epochs completed in 1.885 hours.
# Optimizer stripped from D:\FYP-Tile-Detection\runs\obb\train\weights\last.pt, 42.7MB
# Optimizer stripped from D:\FYP-Tile-Detection\runs\obb\train\weights\best.pt, 42.7MB
#
# Validating D:\FYP-Tile-Detection\runs\obb\train\weights\best.pt...
# Ultralytics 8.3.243  Python-3.14.0 torch-2.9.1+cu130 CUDA:0 (NVIDIA RTX 4000 Ada Generation, 20474MiB)
# YOLO11m-obb summary (fused): 134 layers, 20,879,254 parameters, 0 gradients, 71.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.2it/s 0.9s2.0s
#                    all         24        727      0.987      0.982      0.994      0.952
# Speed: 0.5ms preprocess, 30.6ms inference, 0.0ms loss, 2.4ms postprocess per image
# Results saved to D:\FYP-Tile-Detection\runs\obb\train

# %%
model.save('MJ_tile_detection_yolo11-obb.pt')

# %% [markdown]
# # Task
# Archive the YOLOv8 model training results, including the `runs` directory, into a timestamped zip file and upload it to your Google Drive at `"/content/drive/MyDrive/"`.

# %% [markdown]
# ## Create Timestamped Folder
#
# ### Subtask:
# Create a new folder named with the current date and time.

# %% [markdown]
# **Reasoning**:
# To create a folder with the current date and time as its name, I need to import the `datetime` module to get the current timestamp, format it into a string, and then use the `os` module to create the directory.

# %%
# !zip -r binary_runs.zip runs/
