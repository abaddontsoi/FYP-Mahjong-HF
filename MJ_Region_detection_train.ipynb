# %%
import torch

if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)} is available.")
    device = torch.device("cuda")
else:
    print("No GPU available. PyTorch will run on CPU.")
    device = torch.device("cpu")

print(f"Using device: {device}")
# Out:
# GPU: NVIDIA RTX 4000 Ada Generation is available.
# Using device: cuda

# %%
import torch, torchvision
print("torch:", torch.__version__, "cuda:", torch.version.cuda)
print("torchvision:", torchvision.__version__)
print("cuda available:", torch.cuda.is_available())
# Out:
# torch: 2.9.1+cu130 cuda: 13.0
# torchvision: 0.24.1+cu130
# cuda available: True

# %%
# For normal training
from ultralytics import YOLO

model = YOLO('yolo26m.pt')
# model.reset_weights()


result = model.train(
    data='./yolo11.yaml',
    epochs=50,
    imgsz=1088,
    pretrained=False,
    patience=15,
    device=0,
    optimizer='AdamW'
)
# Out:
# ...
# Ultralytics 8.4.9  Python-3.14.0 torch-2.9.1+cu130 CUDA:0 (NVIDIA RTX 4000 Ada Generation, 20474MiB)
# ...

# %%
model.save('MJ_tile_detection_yolo26.pt')

# %%
# Fine-tune
from ultralytics import YOLO
base_model = YOLO('MJ_tile_detection_yolo26.pt')
new_result = base_model.train(
    data='./yolo11.yaml',
    epochs=20,
    imgsz=1088,
    freeze=10,
    device=0,
    lr0=0.001,
    close_mosaic=10,
)
# Out:
# Ultralytics 8.4.9  Python-3.14.0 torch-2.9.1+cu130 CUDA:0 (NVIDIA RTX 4000 Ada Generation, 20474MiB)
# ...

# %%
base_model.save('MJ_tile_detection_yolo26_fine_tune.pt')

# %%
# For obb
from ultralytics import YOLO

model = YOLO('yolo11m-obb.pt')
# model.reset_weights()


result = model.train(
    data='./yolo11.yaml',
    epochs=50,
    imgsz=1088,
    pretrained=False,
    patience=15,
    device=0,
)
# Out:
# New https://pypi.org/project/ultralytics/8.4.9 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.243  Python-3.14.0 torch-2.9.1+cu130 CUDA:0 (NVIDIA RTX 4000 Ada Generation, 20474MiB)
# ...

# %%
model.save('MJ_tile_detection_yolo11-obb.pt')

# %% [markdown]
# # Task
# Archive the YOLOv8 model training results, including the `runs` directory, into a timestamped zip file and upload it to your Google Drive at `"/content/drive/MyDrive/"`.

# %% [markdown]
# ## Create Timestamped Folder
#
# ### Subtask:
# Create a new folder named with the current date and time.

# %% [markdown]
# **Reasoning**:
# To create a folder with the current date and time as its name, I need to import the `datetime` module to get the current timestamp, format it into a string, and then use the `os` module to create the directory.

# %%
# !zip -r binary_runs.zip runs/
