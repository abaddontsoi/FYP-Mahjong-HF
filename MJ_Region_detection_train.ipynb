# %%
import torch

if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)} is available.")
    device = torch.device("cuda")
else:
    print("No GPU available. PyTorch will run on CPU.")
    device = torch.device("cpu")

print(f"Using device: {device}")
# Out:
# GPU: NVIDIA RTX 4000 Ada Generation is available.
# Using device: cuda

# %%
import torch, torchvision
print("torch:", torch.__version__, "cuda:", torch.version.cuda)
print("torchvision:", torchvision.__version__)
print("cuda available:", torch.cuda.is_available())
# Out:
# torch: 2.9.1+cu130 cuda: 13.0
# torchvision: 0.24.1+cu130
# cuda available: True

# %%
from ultralytics import YOLO

model = YOLO('yolo11m.pt')
# model.reset_weights()


result = model.train(
    data='./yolo11.yaml',
    epochs=50,
    imgsz=1088,
    pretrained=False,
    patience=15,
    device=0,
    optimizer='AdamW'
)
# Out:
# New https://pypi.org/project/ultralytics/8.4.6 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.243  Python-3.14.0 torch-2.9.1+cu130 CUDA:0 (NVIDIA RTX 4000 Ada Generation, 20474MiB)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=./yolo11.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=50, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=1088, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11m.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train5, nbs=64, nms=False, opset=None, optimize=False, optimizer=AdamW, overlap_mask=True, patience=15, perspective=0.0, plots=True, pose=12.0, pretrained=False, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=D:\FYP-Tile-Detection\runs\detect\train5, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  1    111872  ultralytics.nn.modules.block.C3k2            [128, 256, 1, True, 0.25]
#   3                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   4                  -1  1    444928  ultralytics.nn.modules.block.C3k2            [256, 512, 1, True, 0.25]
#   5                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   6                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1   1642496  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    542720  ultralytics.nn.modules.block.C3k2            [1024, 256, 1, True]
#  17                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  20                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1642496  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True]
#  23        [16, 19, 22]  1   1411795  ultralytics.nn.modules.head.Detect           [1, [256, 512, 512]]
# YOLO11m summary: 231 layers, 20,053,779 parameters, 20,053,763 gradients, 68.2 GFLOPs
#
# Transferred 643/649 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4MB 13.7MB/s 0.4s.3s<0.2s.1s
# AMP: checks passed
# train: Fast image access  (ping: 0.00.0 ms, read: 75.945.5 MB/s, size: 350.4 KB)
# train: Scanning D:\FYP-Mahjong-HF\data\train\labels... 568 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 568/568 1.4Kit/s 0.4s<0.1s
# train: New cache created: D:\FYP-Mahjong-HF\data\train\labels.cache
# val: Fast image access  (ping: 0.10.0 ms, read: 44.817.9 MB/s, size: 385.5 KB)
# val: Scanning D:\FYP-Mahjong-HF\data\valid\labels... 178 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 178/178 766.4it/s 0.2s0.0s
# val: New cache created: D:\FYP-Mahjong-HF\data\valid\labels.cache
# Plotting labels to D:\FYP-Tile-Detection\runs\detect\train5\labels.jpg...
# optimizer: AdamW(lr=0.01, momentum=0.937) with parameter groups 106 weight(decay=0.0), 113 weight(decay=0.0005), 112 bias(decay=0.0)
# Image sizes 1088 train, 1088 val
# Using 8 dataloader workers
# Logging results to D:\FYP-Tile-Detection\runs\detect\train5
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      23.2G      1.923      3.275      1.899        242       1088: 100% ━━━━━━━━━━━━ 36/36 7.9s/it 4:437.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.0it/s 6.0s1.3ss
#                    all        178       2740          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50        23G      1.659      1.406      1.793        166       1088: 100% ━━━━━━━━━━━━ 36/36 9.2s/it 5:316.7ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.1it/s 2.8s0.6s
#                    all        178       2740          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      22.6G      1.477      1.146       1.63        209       1088: 100% ━━━━━━━━━━━━ 36/36 6.9s/it 4:105.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.8s/it 10.7s0.9s
#                    all        178       2740          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      22.6G      1.411      1.065      1.587        200       1088: 100% ━━━━━━━━━━━━ 36/36 7.8s/it 4:425.8ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.1s/it 6.9s0.9ss
#                    all        178       2740        0.2     0.0405     0.0483     0.0293
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50      22.7G      1.452      1.096      1.624        209       1088: 100% ━━━━━━━━━━━━ 36/36 8.6s/it 5:097.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.5s/it 9.0s0.8s8
#                    all        178       2740      0.234      0.223      0.174     0.0899
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50        23G      1.355     0.9837      1.567        109       1088: 100% ━━━━━━━━━━━━ 36/36 10.0s/it 5:59.7s6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.6it/s 3.7s0.8ss
#                    all        178       2740      0.813      0.809      0.876      0.549
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50      22.8G       1.28     0.9009      1.481        203       1088: 100% ━━━━━━━━━━━━ 36/36 9.4s/it 5:387.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.8s/it 11.1s0.8s
#                    all        178       2740      0.712       0.53      0.602      0.343
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50        23G      1.224      0.841      1.442        219       1088: 100% ━━━━━━━━━━━━ 36/36 11.2s/it 6:44.4s7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.7s/it 9.9s1.4ss
#                    all        178       2740      0.894      0.904      0.934      0.596
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50      22.8G      1.203     0.8141      1.397        210       1088: 100% ━━━━━━━━━━━━ 36/36 8.0s/it 4:475.7ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.5s/it 8.9s0.8s2
#                    all        178       2740      0.876      0.885      0.932       0.59
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50      22.7G      1.173     0.7859       1.37        200       1088: 100% ━━━━━━━━━━━━ 36/36 7.3s/it 4:224.9ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.0it/s 3.0s0.7s
#                    all        178       2740      0.865       0.92      0.922       0.61
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/50      22.7G      1.104     0.7079      1.324        272       1088: 100% ━━━━━━━━━━━━ 36/36 8.9s/it 5:195.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.5s/it 8.8s0.8s0
#                    all        178       2740      0.886      0.876      0.927      0.623
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/50      22.7G      1.077     0.7009        1.3        262       1088: 100% ━━━━━━━━━━━━ 36/36 7.3s/it 4:245.7ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.1it/s 5.5s1.2ss
#                    all        178       2740      0.921      0.896      0.952      0.659
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/50      23.2G      1.045     0.6732      1.284        145       1088: 100% ━━━━━━━━━━━━ 36/36 8.5s/it 5:066.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.5s/it 9.2s0.7s1
#                    all        178       2740      0.869      0.857      0.911      0.584
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/50        23G       1.01      0.637      1.268        226       1088: 100% ━━━━━━━━━━━━ 36/36 8.8s/it 5:176.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.0it/s 3.0s0.7s
#                    all        178       2740      0.937      0.954      0.964      0.702
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/50      22.8G     0.9917     0.6189      1.227        336       1088: 100% ━━━━━━━━━━━━ 36/36 7.6s/it 4:335.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.4s/it 8.5s0.8s8
#                    all        178       2740      0.913      0.871       0.93       0.64
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/50      22.6G      0.987     0.6099      1.257        192       1088: 100% ━━━━━━━━━━━━ 36/36 5.8s/it 3:293.8ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.0s/it 6.1s1.1ss
#                    all        178       2740      0.932      0.934       0.96      0.703
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/50        23G     0.9983     0.5939      1.233        254       1088: 100% ━━━━━━━━━━━━ 36/36 11.3s/it 6:46.0s3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.4s/it 8.4s0.7s8
#                    all        178       2740      0.948      0.958      0.972      0.738
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/50      22.7G      1.047     0.6101      1.245        210       1088: 100% ━━━━━━━━━━━━ 36/36 5.9s/it 3:343.8ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.0it/s 2.9s0.7s
#                    all        178       2740       0.76      0.529      0.623      0.396
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/50      23.1G      1.013     0.5948       1.23        223       1088: 100% ━━━━━━━━━━━━ 36/36 5.8s/it 3:294.8ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.4s/it 8.6s0.8s9
#                    all        178       2740      0.953      0.975      0.983      0.726
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/50      22.6G     0.9237     0.5547      1.186        263       1088: 100% ━━━━━━━━━━━━ 36/36 5.1s/it 3:033.8ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.0it/s 3.0s0.7s
#                    all        178       2740      0.914      0.893      0.924      0.549
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/50      22.8G     0.9206     0.5489      1.179        284       1088: 100% ━━━━━━━━━━━━ 36/36 7.7s/it 4:395.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.4s/it 8.3s0.8ss
#                    all        178       2740      0.935      0.924      0.964       0.69
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/50      22.7G     0.9004     0.5385      1.166        200       1088: 100% ━━━━━━━━━━━━ 36/36 6.1s/it 3:384.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.5it/s 4.0s0.9ss
#                    all        178       2740      0.846      0.749      0.848       0.57
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/50      22.8G     0.9234     0.5455      1.164        194       1088: 100% ━━━━━━━━━━━━ 36/36 6.9s/it 4:104.9ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.4s/it 8.3s0.8ss
#                    all        178       2740      0.935      0.948      0.972       0.75
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/50      22.7G     0.9017     0.5349      1.163        149       1088: 100% ━━━━━━━━━━━━ 36/36 6.3s/it 3:494.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.0it/s 3.0s0.7s
#                    all        178       2740      0.956      0.982      0.986      0.766
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/50      23.4G     0.8515     0.4854      1.118        250       1088: 100% ━━━━━━━━━━━━ 36/36 5.0s/it 3:014.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.2s/it 7.4s0.9ss
#                    all        178       2740      0.951      0.976      0.983      0.779
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/50      22.6G     0.8692     0.5069      1.151        145       1088: 100% ━━━━━━━━━━━━ 36/36 5.3s/it 3:103.8ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.0it/s 3.0s0.7s
#                    all        178       2740      0.953      0.976      0.981      0.786
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/50      23.8G     0.8379     0.4834      1.115        210       1088: 100% ━━━━━━━━━━━━ 36/36 7.4s/it 4:265.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.2s/it 7.4s0.9ss
#                    all        178       2740      0.964      0.983      0.981      0.776
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/50        22G     0.8437     0.4833      1.125        244       1088: 100% ━━━━━━━━━━━━ 36/36 5.2s/it 3:063.7ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.0s/it 6.0s1.1ss
#                    all        178       2740      0.967      0.986      0.985      0.783
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/50      22.7G     0.8346     0.4773      1.117        170       1088: 100% ━━━━━━━━━━━━ 36/36 5.2s/it 3:074.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.3s/it 8.0s0.8sss
#                    all        178       2740      0.886      0.912      0.941      0.664
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/50      22.6G     0.8038     0.4634      1.083        265       1088: 100% ━━━━━━━━━━━━ 36/36 7.7s/it 4:364.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.1s/it 6.5s1.1ss
#                    all        178       2740      0.962      0.979      0.987       0.79
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/50      23.4G     0.8277     0.4745      1.112        204       1088: 100% ━━━━━━━━━━━━ 36/36 7.7s/it 4:366.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.5s/it 8.9s0.8s4
#                    all        178       2740      0.946      0.976      0.985      0.739
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/50        23G     0.8005     0.4586      1.096        264       1088: 100% ━━━━━━━━━━━━ 36/36 9.5s/it 5:415.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.2it/s 5.1s1.0ss
#                    all        178       2740      0.964       0.98      0.986      0.815
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/50      22.6G     0.8037     0.4467      1.094        236       1088: 100% ━━━━━━━━━━━━ 36/36 9.2s/it 5:336.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.4s/it 8.4s0.7s9
#                    all        178       2740      0.974      0.989      0.988      0.812
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/50      22.6G     0.7977     0.4479      1.091        446       1088: 100% ━━━━━━━━━━━━ 36/36 7.6s/it 4:325.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.9it/s 3.1s0.7s
#                    all        178       2740      0.979      0.989      0.985      0.811
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/50      22.6G     0.7977     0.4441      1.096        201       1088: 100% ━━━━━━━━━━━━ 36/36 6.0s/it 3:354.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.5s/it 9.0s0.8ss
#                    all        178       2740      0.968      0.981      0.985      0.795
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/50      23.9G     0.7749     0.4365      1.086        147       1088: 100% ━━━━━━━━━━━━ 36/36 7.4s/it 4:265.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.3s/it 7.6s0.8sss
#                    all        178       2740      0.969      0.992      0.989      0.826
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/50      22.6G     0.7723     0.4289      1.074        303       1088: 100% ━━━━━━━━━━━━ 36/36 6.1s/it 3:405.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.4s/it 8.7s0.8ss
#                    all        178       2740      0.976      0.982      0.985      0.811
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/50      22.8G      0.773     0.4238      1.072        278       1088: 100% ━━━━━━━━━━━━ 36/36 9.8s/it 5:525.8s2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.1it/s 5.6s1.3ss
#                    all        178       2740      0.961      0.973      0.987      0.788
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/50      22.8G     0.7546     0.4175      1.068        236       1088: 100% ━━━━━━━━━━━━ 36/36 9.0s/it 5:236.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.4s/it 8.5s0.8ss
#                    all        178       2740      0.955      0.972      0.988        0.8
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/50      23.4G     0.7385     0.4098      1.059        241       1088: 100% ━━━━━━━━━━━━ 36/36 5.8s/it 3:304.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.3s/it 7.5s0.9ss
#                    all        178       2740      0.978      0.991       0.99      0.838
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/50      22.6G     0.7263     0.3992      1.077        102       1088: 100% ━━━━━━━━━━━━ 36/36 8.7s/it 5:126.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.7s/it 10.3s0.9s
#                    all        178       2740      0.968      0.987      0.987       0.78
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/50      22.4G     0.7088     0.3889      1.061        100       1088: 100% ━━━━━━━━━━━━ 36/36 4.7s/it 2:493.7ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.0it/s 3.0s0.7s
#                    all        178       2740      0.973       0.99      0.985      0.815
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/50      22.6G     0.7198     0.3965      1.062        138       1088: 100% ━━━━━━━━━━━━ 36/36 5.5s/it 3:194.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.7s/it 10.0s.0ss
#                    all        178       2740      0.979      0.986      0.988      0.821
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/50      22.4G     0.6877     0.3776      1.044        163       1088: 100% ━━━━━━━━━━━━ 36/36 6.9s/it 4:093.9ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.0it/s 5.7s1.3ss
#                    all        178       2740      0.977      0.987      0.989      0.834
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/50      22.7G      0.696     0.3774      1.049        173       1088: 100% ━━━━━━━━━━━━ 36/36 5.5s/it 3:184.7ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.4s/it 8.5s0.8ss
#                    all        178       2740      0.982      0.991       0.99      0.835
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/50      22.6G     0.6711     0.3647      1.037        102       1088: 100% ━━━━━━━━━━━━ 36/36 5.5s/it 3:174.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.1it/s 5.6s1.1ss
#                    all        178       2740       0.98      0.993      0.987      0.836
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50      22.8G     0.6769     0.3622      1.034        137       1088: 100% ━━━━━━━━━━━━ 36/36 10.9s/it 6:33.1s8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.4s/it 8.5s0.8s7
#                    all        178       2740       0.98      0.993      0.991      0.851
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50      22.6G     0.6621     0.3528      1.034        100       1088: 100% ━━━━━━━━━━━━ 36/36 5.6s/it 3:214.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.0it/s 3.0s0.7s
#                    all        178       2740      0.982      0.986      0.991      0.849
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50      22.6G     0.6607     0.3461      1.026        152       1088: 100% ━━━━━━━━━━━━ 36/36 8.9s/it 5:206.7ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.8s/it 10.9s0.8s
#                    all        178       2740       0.98       0.99       0.99      0.852
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50      22.6G     0.6588     0.3418      1.025        130       1088: 100% ━━━━━━━━━━━━ 36/36 6.0s/it 3:364.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.4it/s 4.4s0.9ss
#                    all        178       2740      0.982      0.993      0.988      0.854
#
# 50 epochs completed in 3.832 hours.
# Optimizer stripped from D:\FYP-Tile-Detection\runs\detect\train5\weights\last.pt, 40.6MB
# Optimizer stripped from D:\FYP-Tile-Detection\runs\detect\train5\weights\best.pt, 40.6MB
#
# Validating D:\FYP-Tile-Detection\runs\detect\train5\weights\best.pt...
# Ultralytics 8.3.243  Python-3.14.0 torch-2.9.1+cu130 CUDA:0 (NVIDIA RTX 4000 Ada Generation, 20474MiB)
# YOLO11m summary (fused): 125 layers, 20,030,803 parameters, 0 gradients, 67.6 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.3it/s 4.5s1.0ss
#                    all        178       2740      0.982      0.993      0.988      0.854
# Speed: 0.3ms preprocess, 19.3ms inference, 0.0ms loss, 2.1ms postprocess per image
# Results saved to D:\FYP-Tile-Detection\runs\detect\train5

# %%
model.save('MJ_tile_detection_yolo11.pt')

# %% [markdown]
# # Task
# Archive the YOLOv8 model training results, including the `runs` directory, into a timestamped zip file and upload it to your Google Drive at `"/content/drive/MyDrive/"`.

# %% [markdown]
# ## Create Timestamped Folder
#
# ### Subtask:
# Create a new folder named with the current date and time.

# %% [markdown]
# **Reasoning**:
# To create a folder with the current date and time as its name, I need to import the `datetime` module to get the current timestamp, format it into a string, and then use the `os` module to create the directory.

# %%
# !zip -r binary_runs.zip runs/
# Out:
# 'zip' is not recognized as an internal or external command,
# operable program or batch file.
